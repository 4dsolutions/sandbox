# %% [markdown]
# # Experiments with Excel
#
# Based on [this article](https://davidhamann.de/2018/02/21/read-password-protected-excel-files-into-pandas-dataframe/) by David Hamann.

# %%
import pandas as pd

# %%
df = pd.read_excel("billing_report.xlsx")

# %%
df.head()
# Out:
#                           Unnamed: 0                       Unnamed: 1  \
# 0  Billing Dates from 7/1/20-7/31/20                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                             Line #  Contract Number in Response (1)
#
#         Unnamed: 2                          Unnamed: 3  \
# 0              NaN                                 NaN
# 1              NaN                                 NaN
# 2              NaN                                 NaN
# 3              NaN                                 NaN
# 4  Caseworker Name  Case Number and D2 Referral Number
#
#                    Unnamed: 4           Unnamed: 5  \
# 0  What type of funding?_3580  One (1) Unit =_5328
# 1             Fee for Service         One (1) Hour
# 2                         NaN                  NaN
# ...

# %%
df.tail()
# Out:
#    Unnamed: 0 Unnamed: 1          Unnamed: 2   Unnamed: 3  \
# 45         41     154634  Antoinette Elliott  964374-9213
# 46         42     154634  Antoinette Elliott  964374-9213
# 47         43     154634  Antoinette Elliott  964374-9213
# 48         44     154634    Michelle Zurcher  977824-9758
# 49        NaN        NaN              Count:          NaN
#
#               Unnamed: 4       Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 45  Family SkillBuilders  Manitoba, Amber    6203797       ISRS
# 46  Family SkillBuilders      Oregon, Ava    6203796       ISRS
# 47  Family SkillBuilders  Oregon, Triston    5449996       ISRS
# 48  Family SkillBuilders    Water, Tee'Ra    2133363       ISRS
# 49                   NaN           Count:         38        NaN
#
#        Unnamed: 8           Unnamed: 9  ... Unnamed: 11  Unnamed: 12  \
# 45  Reunification  2020-07-01 00:00:00  ...          60      6.36111
# 46  Reunification  2020-07-01 00:00:00  ...          60      6.36111
# ...

# %%
import os

# %%
>>> os.chdir("C:/Users/Kirby/Downloads/krista_chin")
>>> import xlwings as xw
>>> import pandas as pd
>>> wb = xw.Book("new_template.xlsm")
>>> sheet = "One Twelfth Payments"
>>> sheetname = "One Twelfth Payments"
>>> sheet = wb.sheets[sheetname]
>>> df = sheet['A24:M27'].options(pd.DataFrame, index=False, header=True).value

# %%
df
# Out:
#    Line #        Contract number Caseworker name  Case number  \
# 0     1.0                   None            None          NaN
# 1     1.0  Notes (DHS use only):            None          NaN
# 2     2.0                   1234             fff       3456.0
#
#   Foster provider/\nSubcontractor Participant name  Participant number  \
# 0                            None             None                 NaN
# 1                            None      Payment ID:                 NaN
# 2                             yyy             4567                 6.0
#
#    Service category Service type Service start date  Service end date  \
# 0              None         None               None              None
# 1  Validation code:         None               None  Validation Date:
# 2                65          ttt               None              None
#
#   Number of units Service Outcome
# 0            None             N/A
# 1            None            None
# 2            None             N/A
